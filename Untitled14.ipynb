# %%
# WHILE LOOP

# %%
x=0

while x<5:
    print(f'value of x is {x}')
    x=x+1
# Out:
# value of x is 0
# value of x is 1
# value of x is 2
# value of x is 3
# value of x is 4

# %%
x=0

while x<5:
    print(f'value of x is {x}')
    x+=1
# Out:
# value of x is 0
# value of x is 1
# value of x is 2
# value of x is 3
# value of x is 4

# %%
x=0

while x<5:
    print(f'value of x is {x}')
    x+=1
    
else:
    print("x is not less than 5")
# Out:
# value of x is 0
# value of x is 1
# value of x is 2
# value of x is 3
# value of x is 4
# x is not less than 5

# %%
#keywords(BREAK ,CONTINUE,PASS)

# %%
# PASS

# %%
x=[1,2,3]

for item in x:
    #comment
# Out:
#   File "<ipython-input-30-0f2391bad3f1>", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
x=[1,2,3]

for item in x:
    #comment
    pass


print("end of my script")
# Out:
# end of my script

# %%
x=[1,2,3]

for item in x:
    #comment
    


print("end of my script")
# Out:
#   File "<ipython-input-33-d0a061066508>", line 8
#     print("end of my script")
#     ^
# IndentationError: expected an indented block

# %%
# CONTINUE

# %%
mystring="sammy"

# %%
for letter in mystring:
    print(letter)
# Out:
# s
# a
# m
# m
# y

# %%
mystring='sammy'

# %%
for letter in mystring:
    if letter =='a':
        
        continue
    
    print(letter)
# Out:
# s
# m
# m
# y

# %%
#BREAK

# %%
mystring="sammy"

# %%
for letter in mystring:
    if letter =='a':
        
        break
    
    print(letter)
# Out:
# s

# %%
x=0

while x<5:
